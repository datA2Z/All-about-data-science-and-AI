# %%
# Load Requires packages for analysis
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
plt.rcParams['figure.figsize'] = [12, 10]
os.chdir("F:/Adat Science/Python_Technical_Test")

# %%
#Load data in to python(Pandas) 
data = pd.read_csv("Data.csv")

# %%
# Check the data
data.head(5)
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610   32.985763  150000000  1513528810
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                             homepage          director  \
# ...

# %% [markdown]
# ## Data exploration and visualization

# %%
# Check shape of data
data.shape
# Out:
# (10866, 31)

# %%
# Understand data and variables.
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10866 entries, 0 to 10865
# Data columns (total 31 columns):
# id                       10866 non-null int64
# imdb_id                  10856 non-null object
# popularity               10866 non-null float64
# budget                   10866 non-null int64
# revenue                  10866 non-null int64
# original_title           10866 non-null object
# cast                     10790 non-null object
# homepage                 2936 non-null object
# director                 10822 non-null object
# tagline                  8043 non-null object
# keywords                 9373 non-null object
# overview                 10862 non-null object
# runtime                  10866 non-null int64
# genres                   10843 non-null object
# production_companies     9836 non-null object
# release_date             10866 non-null object
# vote_count               10866 non-null int64
# vote_average             10866 non-null float64
# ...

# %%
data.describe()
# Out:
#                   id    popularity        budget       revenue       runtime  \
# count   10866.000000  10866.000000  1.086600e+04  1.086600e+04  10866.000000
# mean    66064.177434      0.646441  1.462570e+07  3.982332e+07    102.070863
# std     92130.136561      1.000185  3.091321e+07  1.170035e+08     31.381405
# min         5.000000      0.000065  0.000000e+00  0.000000e+00      0.000000
# 25%     10596.250000      0.207583  0.000000e+00  0.000000e+00     90.000000
# 50%     20669.000000      0.383856  0.000000e+00  0.000000e+00     99.000000
# 75%     75610.000000      0.713817  1.500000e+07  2.400000e+07    111.000000
# max    417859.000000     32.985763  4.250000e+08  2.781506e+09    900.000000
#
#          vote_count  vote_average  release_year    budget_adj   revenue_adj
# count  10866.000000  10866.000000  10866.000000  1.086600e+04  1.086600e+04
# mean     217.389748      5.974922   2001.322658  1.755104e+07  5.136436e+07
# ...

# %%
# Let's check how many variables contain missing values and what %
data.isin([0]).sum()/10866 * 100
# Out:
# id                        0.000000
# imdb_id                   0.000000
# popularity                0.000000
# budget                   52.420394
# revenue                  55.365360
# original_title            0.000000
# cast                      0.000000
# homepage                  0.000000
# director                  0.000000
# tagline                   0.000000
# keywords                  0.000000
# overview                  0.000000
# runtime                   0.285294
# genres                    0.000000
# production_companies      0.000000
# release_date              0.000000
# vote_count                0.000000
# vote_average              0.000000
# release_year              0.000000
# budget_adj               52.420394
# revenue_adj              55.365360
# genres1                   0.000000
# genres2                   0.000000
# genres3                   0.000000
# genres3.1                 0.000000
# genres4                   0.000000
# production_companies1     0.000000
# ...

# %%
# Format "budget" and "revenue" Columns
data['budget_mil'] = data['budget'].apply(lambda x: x/1000000)
data['revenue_mil'] = data['revenue'].apply(lambda x: x/1000000)

# %%
data['budget_mil']=data['budget_mil'].replace(0,data['budget_mil'].mean())

# %%
# Let's check how many variables contain missing values
data.isin([0]).sum()/10866 * 100
# Out:
# id                        0.000000
# imdb_id                   0.000000
# popularity                0.000000
# budget                   52.420394
# revenue                  55.365360
# original_title            0.000000
# cast                      0.000000
# homepage                  0.000000
# director                  0.000000
# tagline                   0.000000
# keywords                  0.000000
# overview                  0.000000
# runtime                   0.285294
# genres                    0.000000
# production_companies      0.000000
# release_date              0.000000
# vote_count                0.000000
# vote_average              0.000000
# release_year              0.000000
# budget_adj               52.420394
# revenue_adj              55.365360
# genres1                   0.000000
# genres2                   0.000000
# genres3                   0.000000
# genres3.1                 0.000000
# genres4                   0.000000
# production_companies1     0.000000
# ...

# %%
# Remove unwanted columns to create a heat map
data1 = data.drop(['id','imdb_id','original_title', 'cast', 'homepage', 'director','tagline', 'keywords','genres','production_companies','release_date','vote_count','release_year','budget_adj','revenue_adj','genres1','genres2','genres3','genres3.1','genres4','production_companies1','production_companies2','Unnamed: 28','Unnamed: 29','Unnamed: 30','budget','revenue','overview'], axis = 1)

# %% [markdown]
# ### Heat Map

# %%
# Lets create heat map
correlation = data1.corr()
# display(correlation)
plt.figure(figsize=(14, 12))
heatmap = sns.heatmap(correlation, annot=True, linewidths=0, vmin=-1, cmap="RdBu_r")

# %% [markdown]
# The squares with positive values show direct co-relationships between features. The higher the values, the stronger these relationships are — they’ll be more reddish. That means, if one feature increases, the other one also tends to increase, and vice-versa.
#
# The squares that have negative values show an inverse co-relationship. The more negative these values get, the more inversely proportional they are, and they’ll be more blue. This means that if the value of one feature is higher, the value of the other one gets lower.
#
# Finally, squares close to zero indicate almost no co-dependency between those sets of features.

# %%
# From above we can see that revenue_mil and popularity are high relations. let's plot it
A = data1[['revenue_mil', 'popularity']].copy()
A.head()
# Out:
#    revenue_mil  popularity
# 0  1513.528810   32.985763
# 1   378.436354   28.419936
# 2   295.238201   13.112507
# 3  2068.178225   11.173104
# 4  1506.249360    9.335014

# %%
# Let plot two variables. 
plt.scatter(data['revenue_mil'], data['popularity'],  s = 80, c = 'red')
plt.title("Revenue VS Popularity", fontsize=20)
plt.xlabel("Popularity",fontsize=18)
plt.ylabel("Revenue", fontsize=18)
plt.show()

# %%
# Lets See how many movies Release year
from IPython.display import display, HTML
x = data['release_year'].value_counts(dropna=True, sort=True)
df_value_counts = pd.DataFrame(x)
df_value_counts = df_value_counts.reset_index()
df_value_counts.columns = ['Release year', 'Counts'] # change column names
df_value_counts
# Out:
#     Release year  Counts
# 0           2014     700
# 1           2013     659
# 2           2015     629
# 3           2012     588
# 4           2011     540
# 5           2009     533
# 6           2008     496
# 7           2010     490
# 8           2007     438
# 9           2006     408
# 10          2005     364
# 11          2004     307
# 12          2003     281
# 13          2002     266
# 14          2001     242
# 15          2000     227
# 16          1999     224
# 17          1998     210
# 18          1996     204
# 19          1997     192
# 20          1994     184
# 21          1993     178
# 22          1995     175
# 23          1988     145
# 24          1989     137
# 25          1992     133
# 26          1991     133
# 27          1990     132
# 28          1987     125
# 29          1986     121
# 30          1985     109
# 31          1984     105
# 32          1981      82
# 33          1982      81
# 34          1983      80
# 35          1980      78
# ...

# %%
x.sort_values().plot(kind='barh')
# Add title and axis names
plt.title('Frequency of movis Releases per year',fontsize=20)
plt.xlabel('Counts',fontsize=18)
plt.ylabel('Release year',fontsize=18)

# %%
# Label vote_average column into categorises. (0-5 = Flop, 5-7 = Hit, 7-10 = Super Hit) 
bins = [0,5, 7, 10]
labels = ['Flop', 'Hit', 'Super Hit']

# %%
data['popularity_lab'] = pd.cut(data['vote_average'], bins=bins, labels=labels, include_lowest=True)

# %%
# Separate data by year
is_2011 = data.loc[data['release_year'] == 2011]
is_2012 = data.loc[data['release_year'] == 2012]
is_2013 = data.loc[data['release_year'] == 2013]
is_2014 = data.loc[data['release_year'] == 2014]
is_2015 = data.loc[data['release_year'] == 2015]

# %% [markdown]
# Data visualize by year

# %%
# 2011

categorical_features = ["popularity_lab", "genres1"]
fig, ax = plt.subplots(1, len(categorical_features))
fig.suptitle("Year 2011", fontsize="x-large")
plt.xticks(size = 20)
plt.yticks(size = 20)
#plt.title('Frequency of movis Releases per year',fontsize=20)
for i, categorical_feature in enumerate(is_2011[categorical_features]):
    is_2011[categorical_feature].value_counts().nlargest(5).plot(kind='bar',color=['cyan','skyblue','lightpink','brown','black'],edgecolor = "b", ax=ax[i]).set_title(categorical_feature)
    
fig.show()

# 2012
categorical_features = ["popularity_lab", "genres1"]
fig, ax = plt.subplots(1, len(categorical_features))
fig.suptitle("Year 2012", fontsize="x-large")

#plt.title('Frequency of movis Releases per year',fontsize=20)
for i, categorical_feature in enumerate(is_2012[categorical_features]):
    is_2012[categorical_feature].value_counts().nlargest(5).plot(kind='bar',color=['cyan','skyblue','lightpink','brown','black'],edgecolor = "b", ax=ax[i]).set_title(categorical_feature)
    
fig.show()

# 2013
categorical_features = ["popularity_lab", "genres1"]
fig, ax = plt.subplots(1, len(categorical_features))
fig.suptitle("Year 2013", fontsize="x-large")

#plt.title('Frequency of movis Releases per year',fontsize=20)
for i, categorical_feature in enumerate(is_2013[categorical_features]):
    is_2013[categorical_feature].value_counts().nlargest(5).plot(kind='bar',color=['cyan','skyblue','lightpink','brown','black'],edgecolor = "b", ax=ax[i]).set_title(categorical_feature)
    
fig.show()

# 2014
categorical_features = ["popularity_lab", "genres1"]
fig, ax = plt.subplots(1, len(categorical_features))
fig.suptitle("Year 2014", fontsize="x-large")

#plt.title('Frequency of movis Releases per year',fontsize=20)
for i, categorical_feature in enumerate(is_2014[categorical_features]):
    is_2014[categorical_feature].value_counts().nlargest(5).plot(kind='bar',color=['cyan','skyblue','lightpink','brown','black'],edgecolor = "b", ax=ax[i]).set_title(categorical_feature)
    
fig.show()

# 2015
categorical_features = ["popularity_lab", "genres1"]
fig, ax = plt.subplots(1, len(categorical_features))
fig.suptitle("Year 2015", fontsize="x-large")

#plt.title('Frequency of movis Releases per year',fontsize=20)
for i, categorical_feature in enumerate(is_2015[categorical_features]):
    is_2015[categorical_feature].value_counts().nlargest(5).plot(kind='bar',color=['cyan','skyblue','lightpink','brown','black'],edgecolor = "b", ax=ax[i]).set_title(categorical_feature)
    
fig.show()
# Out:
# C:\Users\pc\Anaconda3\lib\site-packages\matplotlib\figure.py:402: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %% [markdown]
# Let's find relationship genres1, revenue_mil, and budget_mil

# %%
data_re = data[['genres1', 'revenue_mil','budget_mil']]

# %%
data_re.head(2)
# Out:
#   genres1  revenue_mil  budget_mil
# 0  Action  1513.528810       150.0
# 1  Action   378.436354       150.0

# %%
data_re.shape
# Out:
# (10866, 3)

# %%
# Remove all zeros from data
data_s = data_re[data_re.revenue_mil != 0]

# %%
data_s.shape
# Out:
# (4850, 3)

# %%
data_s.head(2)
# Out:
#   genres1  revenue_mil  budget_mil
# 0  Action  1513.528810       150.0
# 1  Action   378.436354       150.0

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="ticks", color_codes=True)
sns.set(font_scale=1)

# %%
# Create boxplot for each genres1
sns.catplot(x="genres1", y="revenue_mil", kind="box", data=data_s, height=9, aspect=2);

# %%
labes = sorted(set(data_s.genres1))

# %% [markdown]
# Loop over each label to create scatterplot

# %%
for lab in labes:
    #print (i)
    data_labels = data_s[data_s.genres1 == lab]
    plt.scatter(data_labels.revenue_mil,data_labels.budget_mil,15)
    plt.title(lab)
    plt.show()

# %% [markdown]
# # K means clustering

# %%
# We use some varables (runtime","vote_average)
A = data[["runtime","vote_average"]]
X = data[["runtime","vote_average"]].values

# %%
# Using the elbow method to find the optimal number of clusters
from sklearn.cluster import KMeans
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 42)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)
plt.plot(range(1, 11), wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
# Fitting K-Means to the dataset
kmeans = KMeans(n_clusters = 3, init = 'k-means++', random_state = 42)
y_kmeans = kmeans.fit_predict(X)
A["Clusters"] = y_kmeans
# Out:
# C:\Users\pc\Anaconda3\lib\site-packages\ipykernel\__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# Visualising the clusters
plt.scatter(X[y_kmeans == 0, 0], X[y_kmeans == 0, 1], s = 100, c = 'red', label = 'Cluster 1')
plt.scatter(X[y_kmeans == 1, 0], X[y_kmeans == 1, 1], s = 100, c = 'blue', label = 'Cluster 2')
plt.scatter(X[y_kmeans == 2, 0], X[y_kmeans == 2, 1], s = 100, c = 'green', label = 'Cluster 3')
#plt.scatter(X[y_kmeans == 3, 0], X[y_kmeans == 3, 1], s = 100, c = 'cyan', label = 'Cluster 4')
#plt.scatter(X[y_kmeans == 4, 0], X[y_kmeans == 4, 1], s = 100, c = 'magenta', label = 'Cluster 5')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s = 300, c = 'yellow', label = 'Centroids')
plt.title('Clusters of customers')
plt.xlabel('Annual Income (k$)')
plt.ylabel('Spending Score (1-100)')
plt.legend()
plt.show()

# %%
# Data with its clusters number
A.head(5)
# Out:
#    runtime  vote_average  Clusters
# 0      124           6.5         0
# 1      120           7.1         0
# 2      119           6.3         0
# 3      136           7.5         0
# 4      137           7.3         0
